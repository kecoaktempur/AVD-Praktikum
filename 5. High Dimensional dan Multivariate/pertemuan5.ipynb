# %% [markdown]
# # Pertemuan 5 - High Dimensional dan Multivariate
# Ferry Triwantono - 082111633094

# %%
# Import Package dan Library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
# Import Dataset
data_1 = pd.read_csv(r"D:\Coolyeah\Mata Kuliah\SMT 5\Analisis Visualisasi Data Praktikum\5. High Dimensional dan Multivariate\shopping_data.csv")

col_1 = data_1['Age']
col_2 = data_1['Annual Income']
col_3 = data_1['Spending Score']

df_3d = pd.DataFrame([col_1.head(20), col_2.head(20), col_3.head(20)]).transpose()
df_3d
# Out:
#     Age  Annual Income  Spending Score
# 0    23             15              39
# 1    21             15              81
# 2    20             16               6
# 3    23             16              77
# 4    31             17              40
# 5    22             17              76
# 6    35             18               6
# 7    23             18              94
# 8    64             19               3
# 9    30             19              72
# 10   67             19              14
# 11   35             19              99
# 12   58             20              15
# 13   24             20              77
# 14   37             20              13
# 15   22             20              79
# 16   35             21              35
# 17   20             21              66
# 18   52             23              29
# 19   35             23              98

# %% [markdown]
# 1. Diagram Batang

# %%
colors_1 = ['r', 'b', 'g', 'y', 'b', 'w']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
age_annual = df_3d.groupby(['Age', 'Annual Income']).size().reset_index(name='Count')
for i, spec in enumerate(age_annual['Annual Income']):
    ax.bar(col_2.head(20), col_3.head(20), zs=i, zdir='y', alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %% [markdown]
# 2. Diagram Batang Multiple Dataframes

# %%
columns = ['A', 'B', 'C']
df_name = ['Age', 'Annual Income', 'Spending Score']
colors_3 = ('r', 'g', 'b')

main_df = [df_3d]

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.xticks([i for i in range(len(columns))], columns)
plt.yticks([i for i in range(len(df_name))], df_name)

xs = []
for i in range(len(main_df)):
    for j in range(len(columns)):
        xs.append(i + j * 0.1)

for c1, color in enumerate(colors_3):
    x = data_1['Age'].head(3)
    y = data_1['Annual Income'].head(3)
    z = data_1['Spending Score'].head(3)

    ax.bar(xs, y, z, zdir='y', alpha=0.8, color=colors_3)

plt.title('Multiple DataFrames')
plt.show()

# %% [markdown]
# 3. ScatterPlot

# %%
data = [col_1, col_2, col_3]

colors_3 = ('r', 'g', 'b')
groups = ['Age', 'Annual Income', 'Spending Score']

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

cmap = ListedColormap(sns.color_palette("husl", 256).as_hex())
ax.scatter(x, y, z, c=col_1, marker ='o', cmap=cmap)

plt.title('3D Scatterplot')
plt.show()

# %%
# coba
coba_columns = ['A', 'B', 'C']
coba_names = ['Age', 'Annual Income', 'Spending Score']

coba_df = [pd.DataFrame([col_1.head(3), col_2.head(3), col_3.head(3)], columns=columns), pd.DataFrame([col_1.head(3), col_2.tail(3), col_3.tail(3)], columns=columns), pd.DataFrame([col_1.tail(3), col_1.tail(3), col_1.tail(3)], columns=columns)]

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

plt.xticks([i for i in range(len(coba_columns))], coba_columns)
plt.yticks([i for i in range(len(coba_names))], coba_names)

xs = []
for i in range(len(coba_df)):
    for j in range(len(coba_columns)):
        xs.append(i + j * 0.1)

for c1, color in enumerate(colors_3):
    for i in range(len(coba_columns)):
        x = [xi, 0.1 * i for xi in xs]
        y = [j for j in range(len())]
    ax.bar(xs, y, zs=c1, zdir='y', color=cs, alpha=0.5, width=0.1)

plt.show()
# Out:
#   Cell In[137], line 20
#     x = [xi, 0.1 * i for xi in xs]
#          ^
# SyntaxError: did you forget parentheses around the comprehension target?
